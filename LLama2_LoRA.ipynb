# %% [markdown]
# ## 1. Install necessary libraries

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %% [markdown]
# ## 2. Dataset details

# %% [markdown]
# You can download the dataset including two csv files [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/) (departments.csv and products.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Data
# Out:
# departments.csv  products.csv

# %%
import pandas as pd
df_product = pd.read_csv('/content/drive/MyDrive/Data/products.csv')
df_depart = pd.read_csv('/content/drive/MyDrive/Data/departments.csv')
df_joined = pd.merge(df_product, df_depart, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row : row['product_name'] + ' --> ' + row['department'], axis=1)
df_joined.head()
# Out:
#    product_id                                 product_name  aisle_id  \
# 0           1                   Chocolate Sandwich Cookies        61
# 1          16                Mint Chocolate Flavored Syrup       103
# 2          25      Salted Caramel Lean Protein & Fiber Bar         3
# 3          32                Nacho Cheese White Bean Chips       107
# 4          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#    department_id department                                               text
# 0             19     snacks              Chocolate Sandwich Cookies --> snacks
# 1             19     snacks           Mint Chocolate Flavored Syrup --> snacks
# 2             19     snacks  Salted Caramel Lean Protein & Fiber Bar --> sn...
# 3             19     snacks           Nacho Cheese White Bean Chips --> snacks
# 4             19     snacks  Organic Sourdough Einkorn Crackers Rosemary --...

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, train_size=0.8, random_state=1)

# %%
from datasets import Dataset, DatasetDict
train_dataset_dict = DatasetDict({
    "train" : Dataset.from_pandas(train_df)
})

# %% [markdown]
# ## 3. Load LLama2-7b-chat model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoConfig

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{torch.cuda.current_device()}' if torch.cuda.is_available() else 'cpu'

bnb_config = BitsAndBytesConfig(
    load_in_4bit = True,
    bnb_4bit_quant_type = 'nf4',
    bnb_4bit_use_double_quant = True,
    bnb_4bit_compute_dtype= torch.bfloat16
)

hf_auth = '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'
model_config = AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)

model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %%
print(f"Model loaded on {device}")
# Out:
# Model loaded on cuda:0

# %% [markdown]
# ## Load the tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth,
    trust_remote_code = True
)
tokenizer.pad_token = tokenizer.eos_token
tokenizer
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-chat-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False), 'pad_token': '</s>'}, clean_up_tokenization_spaces=False)

# %% [markdown]
# ## 4. Check the output of base model before fine tuning

# %%
import transformers

pipeline = transformers.pipeline(
    'text-generation',
    model = model,
    tokenizer = tokenizer,
    torch_dtype = torch.bfloat16,
    trust_remote_code = True,
    device_map = "auto"
)

sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Result: “Free & Clear Stage 4 Overnight Diapers” ->: “Free & Clear Stage 4 Overnight Diapers” ->: “Free & Clear Stage 4 Overnight Diapers” ->: “Free & Clear Stage 4 Overnight Diapers”
#
# You can repeat this process as many times as you want, but keep in mind that the more times you repeat it, the more times you'll have to enter the same information.
# Alternatively, you can use a spreadsheet or a database management system to keep track of the information and automate the process of entering it into the diaper size chart. This can save you a lot of time and effort in the long run.
# I hope this helps! Let me know if you have any other questions.
# Result: Bread Rolls ->: 2022-01-26 17:55:00
#  hopefully you will like it.
# Result: French Milled Oval Almond Gourmande Soap ->:
#  Einzelnes ->: 0,75 €/ Stck.
#
# Total ->: 6,25 €
#
# Is this correct?
#
# Answer: No, the calculation is incorrect.
#
# The cost of 10 individually-wrapped French Milled Oval Almond Gourmande soaps is:
#
# 10 x 0,75 €/Stck. = 7,50 €
#
# So, the total cost is:
# Total ->: 7,50 €

# %% [markdown]
# ## 5. Load the trainer

# %% [markdown]
# ### Below we will load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance.

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha = lora_alpha,
    lora_dropout = lora_dropout,
    r = lora_r,
    bias = "none",
    task_type = "CAUSAL_LM",
    target_modules=["q_proj","v_proj"]
)

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size = per_device_train_batch_size,
    gradient_accumulation_steps = gradient_accumulation_steps,
    optim = optim,
    save_steps = save_steps,
    logging_steps = logging_steps,
    learning_rate = learning_rate,
    fp16 = True,
    max_grad_norm = max_grad_norm,
    max_steps = max_steps,
    warmup_ratio = warmup_ratio,
    group_by_length = True,
    lr_scheduler_type = lr_scheduler_type,
)

# %% [markdown]
# Pass everything to the trainer

# %%
from trl import SFTTrainer

max_seg_length = 512

trainer = SFTTrainer(
    model = model,
    train_dataset = train_dataset_dict['train'],
    peft_config = peft_config,
    dataset_text_field = 'text',
    max_seq_length = max_seg_length,
    tokenizer = tokenizer,
    args = training_arguments,
)
trainer
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:119: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]

# %% [markdown]
# Pre-process the model by upcasting the layer norms in float32 for more stable training

# %%
for name, module in trainer.model.named_modules():
  if 'norm' in name:
    module = module.to(torch.float32)

# %% [markdown]
# ## 6. Train the model
#
# Now let's train the model. Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: ERROR API key must be 40 characters long, yours was 37
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: ERROR API key must be 40 characters long, yours was 37
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/content/wandb/run-20230808_143019-2ayilpei</code>
# Syncing run <strong><a href='https://wandb.ai/mino-gang/huggingface/runs/2ayilpei' target="_blank">glorious-sea-1</a></strong> to <a href='https://wandb.ai/mino-gang/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mino-gang/huggingface' target="_blank">https://wandb.ai/mino-gang/huggingface</a>
#  View run at <a href='https://wandb.ai/mino-gang/huggingface/runs/2ayilpei' target="_blank">https://wandb.ai/mino-gang/huggingface/runs/2ayilpei</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 11:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.886700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.276200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.240300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.226800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.109400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.487500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.094600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.034000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.182100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.840100</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.970700</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.819600</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.713000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.783200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.490700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.434600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.337400</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.153000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.634600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.982400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.836600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.656800</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.738300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.974100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.701600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.794600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.628400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.501600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.395300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.461800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.554500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.689300</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.686500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2.257200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.371200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.220800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.595800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.697800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.439100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.982500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.390500</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.289900</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.779900</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.866500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.075200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>2.334700</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.587800</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>2.446200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.761200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.275100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>3.706800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.420000</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.993600</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.786600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.835700</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.581500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.140900</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.268500</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.558800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.711700</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.339700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>2.248800</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.244100</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>2.352000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.391000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>2.181100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>2.287500</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.426400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>2.300300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.307600</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.109500</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>2.295100</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>2.309400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.969600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.914800</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.328100</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.338700</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.865500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.970500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.532200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.286200</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.376100</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>2.444200</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.215400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>2.274100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.340900</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.101400</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>2.229700</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>2.481000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.883600</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2.122600</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>2.184900</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>2.067500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.960400</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.243700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.779500</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.318800</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>2.486700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>2.462800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.065800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>3.034600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>2.995500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.674600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.758900</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>2.291900</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.291700</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.109300</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.227500</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.575500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.174200</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.186600</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.004700</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>2.096600</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.415100</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.223100</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.187600</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>2.048200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>2.206400</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.989000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.369900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.6549172540505728, metrics={'train_runtime': 904.4487, 'train_samples_per_second': 2.123, 'train_steps_per_second': 0.133, 'total_flos': 598065665310720.0, 'train_loss': 2.6549172540505728, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model = model,
    tokenizer = tokenizer,
    torch_dtype = torch.float16,
    trust_remote_code = True,
    device_map = "auto"
)

sequences = pipeline(
    lst_test_data_short,
    max_length = 100,
    do_sample = True,
    top_k = 10,
    num_return_sequences = 1,
    eos_token_id = tokenizer.eos_token_id
)

for ix, seq in enumerate(sequences):
  print(ix,seq[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 0 Soothing Bath Treatment --> personal care bath/body wash --> bath --> body care --> dry skin care --> body wash --> personal care --> dry skin wash --> bath care --> body wash for dry skin --> dry skin bath wash --> luxury dry skin wash --> body wash for dry skin care --> dry skin wash --> dry skin body wash --> dry skin bath body wash --> body wash for dry skin --> dry skin wash for body --> lux
# 1 Carbon Filtered Water --> beverages and drinks --> water --> still water --> carbon filtered water --> sparkling water --> flavored sparkling water --> lemonade --> lemonade with green tea --> iced tea --> iced tea with lemon --> iced tea with lemon and green tea --> juice --> juice drinks --> fruit drinks --> sports drinks --> energy drinks --> energy shots --> energy mixes --> coffee and tea --> hot beverages
# 2 Breakfast On The Go! Berry Nut Blend Nut & Granola Mix --> breakfast cereals eggs baking goods produce dairy meats seafood --> dairy eggs produce frozen foods household cleaning products baby products personal care pet products household pantry items baking supplies --> baking goods baking mixes baking powder & baking soda --> baking powder & baking soda baking supplies cooking utensils kitchen gadgets
# 3 Organic Sensible Sipper Apple Juice --> beverages --> fruit beverages --> juice --> apple juice --> juice --> apple juice organic 100% juice --> beverages --> drinks --> fruit drinks --> juice drinks --> apple juice drinks --> sensable sipper apple juice --> beverages --> drinks --> fruit drinks --> juice drinks --> apple juice drinks --> Organic Sensible
# 4 Parchment Baking Paper --> pantry dry goods snacks baking supplies --> parchment paper --> parchment baking paper --> paper towels --> paper towels --> paper towels, extra absorbent --> cleaning supplies --> paper towels, extra absorbent, large roll --> cleaning supplies --> paper towels, extra absorbent, large roll --> kitchen utensils and gadgets --> kitchen utensils --> cleaning
# 5 Chicken Fingers With Macaroni & Cheese --> frozen foods seafood and fish frozen meals and dinners --> frozen foods seafood and fish frozen meals and dinners --> frozen meals and dinners --> frozen entree meals --> frozen chicken and rice dishes --> frozen chicken dinners --> frozen chicken entree dishes --> frozen chicken --> chicken dishes frozen entrees -->
# 6 Naked Blues --> snacks sea salt & pepper almonds --> snacks pistachios with Dark Chocolate Coating --> snacks mixed berries --> snacks crunchy peanut butter --> snacks sweet & salty mix --> snacks pumpkin seeds chocolate chip --> snacks roasted cashews --> snacks sea salt & roasted garlic almonds --> snacks chocolate chunky granola --> snacks c
# 7 Lori's Lemon Tea --> beverages tea iced tea --> beverages tea iced tea tea bags --> house beverages --> beverages tea iced tea --> beverages bubble tea --> beverages bubble tea --> beverages iced tea --> beverages tea --> beverages coffee/coffee/baby food/baby snacks/pantry goods/pantry cleaning products/personal care/pet
# 8 Key Lime Pie --> snacks bread snacks frozen meals ice cream frozen yogurt ice cream novelties ice cream sandwichs frozen desserts --> frozen novelties --> frozen pies and cobblers --> pie snacks fruit pies frozen dessert sandwiches fruit parfaits frozen cakes and pies frozen dessert bars fruit parfaits ice cream sandwichs --> snacks bread sn
# 9 Orange Drink Mix --> beverages --> drinks --> powder drink mixes --> orange --> beverages --> drinks --> powder drink mixes --> fruit flavors --> beverages --> drinks --> powder drink mixes --> orange fruit flavor --> beverages --> drinks --> powder drink mixes --> fruit flavors --> pineapple --> beverages --> drinks --> powder drink mixes --> fruit flavors --> pineapple fruit flavor -->
# 10 Apple Juice Cocktail --> beverages beverages juices fruit juice drinks juice cocktails drink mix fruit punch --> beverages juices fruit juice drinks juice cocktails drink mix fruit punch --> alcoholic beverage spirits fruit liqueurs liqueurs --> other beverages non-alcoholic beverages fruit juice drinks --> snacks snack bars --> other snacks fruit juice sn
# 11 Free & Clear Unscented Laundry Detergent Packs --> household supplies laundry detergent packs --> personal care laundry detergent free & clear --> laundry detergent --> laundry detergent packs --> clear laundry detergent packs --> free clear laundry detergent --> cleaning laundry detergent --> detergent --> free clear liquid laundry detergent --> laundry d
# 12 Naturals Cough & Throat Relief Nighttime Drink Mix Powder, Honey Lemon --> personal care products cough & throat relief cough drop honey and lemon --> personal care products cough drops cough and cold medicine --> personal care products cough drops cough drops with menthol and eucalyptus oil --> personal care products cough drops honey and lemon cough and cold medicine --> personal care products cough lo
# 13 Blue Tilapia Fillets --> meat seafood seafood fish --> frozen seafood --> fish fillets --> tilapia frozen --> blue tilapia fillets --> wild caught --> frozen fish --> blue tilapia fillets wild caught frozen --> fish fillets seafood frozen seafood --> fish seafood --> frozen seafood seafood frozen meat --> blue tilapia fillets wild caught frozen --> frozen
# 14 Compact Emeryl File --> other household supplies personal care --> personal care tools and accessories --> emery boards --> emery boards with handle and emery file --> Emery Board with Handle & Emery File --> household supplies emery boards emery files --> personal care tools and accessories --> emery boards with handle and emery file --> emery boards with handle and emery file --> personal care tools and accessories --> personal care tools and accessories emery
# 15 87% Dark Stone Ground Organic Chocolate --> snacks missing nutrition facts --> dark chocolate bar --> missing nutrition facts --> organic chocolate bar missing nutrition facts --> nutritional information missing --> 87% Dark Stone Ground Organic Chocolate --> snacks missing nutrition facts --> dark chocolate bar --> missing nutrition facts --> organic chocolate bar missing nutrition facts --> nutr
# 16 Set & Refresh Linen & Sky Scent Air Freshener Refill --> household supplies pets cleaning supplies laundry supplies air fresheners & scents personal care cosmetics skincare hair care baby & kid supplies toiletries towables paper products & plasticware home & outdoor decor home improvement tools & building materials furniture & decor textiles & sewing crafts & hobbies sports & outdoors electronics & photo musical instruments &
# 17 Mortadella --> deli meats cheese --> meats --> cheese --> bakery --> dairy --> produce --> household staples --> pantry --> health & household --> personal care & beauty --> baby & toddler care --> baby food & formula --> baby supplies --> toddler supplies --> toys & games --> books & media --> entertainment --> household electronics --> office & school supplies --> arts & crafts --> outdoor & sports --> home & garden --> outdoors
# 18 Zinc & Sage Shampoo --> personal care products --> hair care --> shampoos --> sulfate free shampoos --> zinc & sage shampoo --> zinc and sage shampoo for sensitive scalps --> hair care --> shampoos --> sulfate free shampoos --> zinc and sage shampoo for sensitive scalps --> hair care --> shampoos --> sulfate free sham
# 19 Chicken Corn Taquitos --> frozen appetizers seafood --> frozen snacks and appetizers seafood --> frozen snacks and appetizers seafood --> fried foods seafood snacks --> frozen snacks seafood --> snacks frozen snacks seafood fried --> fried snacks seafood --> snacks fried seafood --> frozen appetizers seafood fried --> fried app
# 20 Pasta Sauce, Authentic, Bistro Marinara --> dry goods pasta --> pantry goods sauces --> pantry pasta sauces --> pasta sauce --> marinara pasta sauce --> marinara --> sauces seafood pasta soup --> frozen seafood pasta soups --> frozen seafood soups --> seafood pasta soup --> seafood soups seaweed snacks salty seaweed --> sn
# 21 Mango Lemonade --> beverages --> fruit drinks --> smoothies --> fruit smoothies --> pineapple mango passionfruit smoothie --> beverages --> smoothies --> dairy free smoothies --> fruit smoothies --> pineapple mango passionfruit smoothie --> beverages --> fruit drinks --> smoothies --> pineapple mango passionfruit smoothie --> beverages --> smoothies --> fruit smoothies --> pineapple mango passionf
# 22 Paleo English Muffins --> bakery pastries frozen eggs dairy meat seafood ice cream/ frozen yogurt snacks --> frozen foods pasta & rice beverages snack foods cheese eggs & dairy frozen fruit & vegetables breads, rolls, pizza crusts cereals, granola & bars snack bars & trail mixes frozen fruit & veggie burgers & sandwiches --> free
# 23 Wild Alaskan Fish Oil 1000mg --> personal care products --> vitamins/supplements --> fish oil supplements --> Wild Alaskan Fish Oil 1000 mg --> supplements nutrition --> omega 3 supplements --> Fish Oil supplements --> Alaskan fish oil --> omega 3 fatty acids --> fish oil --> wild alaskan fish oil 1000 m
# 24 Organic Cashew Cacao Cookie Dough Butter --> pantry items pasta sauce --> snacks & beverages --> frozen foods --> frozen desserts --> frozen ice cream --> frozen yogurt --> frozen custards --> frozen novelties --> frozen novelty ice cream --> frozen novelty frozen yogurt --> frozen novelty frozen custard --> frozen novelty frozen ice cream -->

# %%
def correct_answer(ans):
  return (ans.split("-->")[1]).strip()

answers = []
for ix,seq in enumerate(sequences):
    # print(ix,seq[0]['generated_text'])
    answers.append(correct_answer(seq[0]['generated_text']))

df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name       department  \
# 0                             Soothing Bath Treatment    personal care
# 1                               Carbon Filtered Water        beverages
# 2   Breakfast On The Go! Berry Nut Blend Nut & Gra...        breakfast
# 3                 Organic Sensible Sipper Apple Juice        beverages
# 4                              Parchment Baking Paper           pantry
# 5              Chicken Fingers With Macaroni & Cheese           frozen
# 6                                         Naked Blues           snacks
# 7                                    Lori's Lemon Tea        beverages
# 8                                        Key Lime Pie           snacks
# 9                                    Orange Drink Mix        beverages
# 10                               Apple Juice Cocktail        beverages
# 11     Free & Clear Unscented Laundry Detergent Packs        household
# 12  Naturals Cough & Throat Relief Nighttime Drink...    personal care
# 13                               Blue Tilapia Fillets     meat seafood
# 14                                Compact Emeryl File            other
# 15            87% Dark Stone Ground Organic Chocolate           snacks
# 16  Set & Refresh Linen & Sky Scent Air Freshener ...        household
# 17                                         Mortadella             deli
# 18                                Zinc & Sage Shampoo    personal care
# 19                              Chicken Corn Taquitos           frozen
# 20            Pasta Sauce, Authentic, Bistro Marinara  dry goods pasta
# 21                                     Mango Lemonade        beverages
# 22                              Paleo English Muffins           bakery
# 23                       Wild Alaskan Fish Oil 1000mg    personal care
# 24           Organic Cashew Cacao Cookie Dough Butter           pantry
#
#                                  department_predicted
# 0                        personal care bath/body wash
# 1                                beverages and drinks
# 2   breakfast cereals eggs baking goods produce da...
# 3                                           beverages
# 4             pantry dry goods snacks baking supplies
# 5   frozen foods seafood and fish frozen meals and...
# 6                    snacks sea salt & pepper almonds
# 7                              beverages tea iced tea
# 8   snacks bread snacks frozen meals ice cream fro...
# 9                                           beverages
# 10  beverages beverages juices fruit juice drinks ...
# 11         household supplies laundry detergent packs
# 12  personal care products cough & throat relief c...
# 13                          meat seafood seafood fish
# 14             other household supplies personal care
# 15                     snacks missing nutrition facts
# 16  household supplies pets cleaning supplies laun...
# 17                                  deli meats cheese
# 18                             personal care products
# 19                          frozen appetizers seafood
# 20                                    dry goods pasta
# 21                                          beverages
# 22  bakery pastries frozen eggs dairy meat seafood...
# 23                             personal care products
# 24                           pantry items pasta sauce
